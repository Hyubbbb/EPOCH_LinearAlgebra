# %%
import numpy as np
import plotly.graph_objects as go
import random

# %% [markdown]
# ### 연습문제 2-1

# %%
s1 = 1
s2 = 2
s3 = -3

v1 = np.array([4,5,1])
v2 = np.array([-4,0,-4])
v3 = np.array([1,3,2])

print(s1*v1 + s2*v2 + s3*v3)

scalar = np.array([1,2,-3])
vector = np.array([v1,v2,v3])


print(sum(s*v for s,v in zip(scalar, vector)))

# np.zeros()로 초기화하는 이유가 뭐지?
# Out:
# [ -7  -4 -13]
# [ -7  -4 -13]

# %% [markdown]
# ### 연습문제 2-3

# %%
v = np.array([1,3])
numbers=[]
for i in range(1,10):
  number=random.uniform(-4,4)
  numbers.append(number)

def sample(num_points, xrange, yrange):
    points = [] # 그려야 할 그림의 점 좌표

    for i in range(numbers):
      numbers * v

xrange = [-4, 4]
yrange = [-4, 4]
points = sample(
    100,
    xrange,
    yrange)

plt.scatter(points[:, 0], points[:, 1], c='blue', s=0.1)




# fig = go.Figure( data=[go.Scatter3d(
#     x=points[-4:4,0], y=points[-4:4,1],
#     mode='markers' )])
# fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-5603a7dd6c78> in <cell line: 15>()
#      13 xrange = [-4, 4]
#      14 yrange = [-4, 4]
# ---> 15 points = sample(
#      16     100,
#      17     xrange,
#
# <ipython-input-14-5603a7dd6c78> in sample(num_points, xrange, yrange)
#       8     points = [] # 그려야 할 그림의 점 좌표
#       9
# ---> 10     for i in range(numbers):
#      11       numbers * v
#      12
#
# TypeError: 'list' object cannot be interpreted as an integer
