# %% [markdown]
# # Exercise 1

# %%
# 벡터 더하기 연습
v = np.array([1,2])
w = np.array([4,-6])
vPlusW = v+w

# 세 벡터 출력
print(v)
print(w)
print(vPlusW)

# 그래프 그리기
plt.figure(figsize=(6,6))
a1 = plt.arrow(0,0,v[0],v[1],head_width=.3,width=.1,color='k',length_includes_head=True)
a2 = plt.arrow(v[0],v[1],w[0],w[1],head_width=.3,width=.1,color=[.5,.5,.5],length_includes_head=True)
a3 = plt.arrow(0,0,vPlusW[0],vPlusW[1],head_width=.3,width=.1,color=[.8,.8,.8],length_includes_head=True)
plt.grid(linestyle='--',linewidth=.5)
plt.axis('square')
plt.axis([-6,6,-6,6])
plt.legend([a1,a2,a3],['v','w','v+w'])
plt.title('벡터 $\mathbf{v}$, $\mathbf{w}$, $\mathbf{v+w}$')
plt.savefig('Figure_01_02a.png',dpi=300)
plt.show()

# %% [markdown]
# # Exercise 2

# %%
# 벡터 노름 함수 정의
def normOfVect(v):
  return np.sqrt(np.sum(v**2))

# 유닛 노름 벡터 테스트
w = np.array([0,0,1])
print( normOfVect(w) )

# np.linalg.norm와 비교
w = np.array([1,2,3])
print( normOfVect(w),np.linalg.norm(w) )

# %%
import plotly.graph_objects as go

# 두 벡터를 R3 공간에서 정의
v1 = np.array([ 3,5,1 ])
v2 = np.array([ 0,2,2 ])

## 아래 코드를 주석 해제하여 두 번째 부분을 수행
# v1 = np.array([ 3.0,5.0,1.0 ])
# v2 = np.array([ 1.5,2.5,0.5 ])

# x축 범위에서 무작위 스칼라 값 생성
scalars = np.random.uniform(low=xlim[0],high=xlim[1],size=(100,2))

# 무작위 점 생성
points = np.zeros((100,3))
for i in range(len(scalars)):
  points[i,:] = v1*scalars[i,0] + v2*scalars[i,1]  # 벡터들의 가중합

# 평면에 점들을 그림
fig = go.Figure( data=[go.Scatter3d(x=points[:,0], y=points[:,1], z=points[:,2],
                                    mode='markers', marker=dict(size=6,color='black') )])

fig.update_layout(margin=dict(l=0,r=0,b=0,t=0))
fig.show()
